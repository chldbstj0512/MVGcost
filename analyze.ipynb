# %%
import pandas as pd

df = pd.read_csv("logs/access_cost_log.csv")

df["request_cost"].describe(percentiles=[0.5, 0.95])
# Out:
# count    60.000000
# mean      0.000035
# std       0.000016
# min       0.000000
# 50%       0.000040
# 95%       0.000050
# max       0.000054
# Name: request_cost, dtype: float64
